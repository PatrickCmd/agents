# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

import json
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import pymupdf.layout  # activate PyMuPDF-Layout in pymupdf
import pymupdf4llm
# pip install markitdown
from markitdown import MarkItDown
import gradio as gr
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
display(Markdown(linkedin))
# Out:
#
# Contact
# p.walukagga@gmail.com
# www.linkedin.com/in/patrick-
# walukagga-53261382 (LinkedIn)
# Top Skills
# Large Language Models (LLM)
# Shell Scripting
# Cloud Computing
# Certifications
# Programming for Everybody (Getting
# Started with Python)
# Front-End Web UI Frameworks and
# Tools
# AWS Cloud Project Bootcamp (Teal
# Squad)
# GitHub Copilot
# Python Data Structures
# PATRICK WALUKAGGA
# Software Engineer (Python Backend) | Cloud Data Engineer | 2x
# AWS
# Uganda
# Summary
# Passionate Back-End Developer with 4 years of experience in
# software development. Skilled in building scalable and testable
# back-end solutions using Python, Django, and PostgreSQL and
# I have experience working with Flask, GraphQL, Pandas, and
# NumPy. Patrick is a lifelong learner who constantly seeks to learn
# new technologies and is interested in Data Engineering, Big Data,
# Machine Learning, Deep Learning, and MLOPs.
# Skills: Python, Django/Flask/FastAPI, SQL, GCP,  Scikit-Learn, AWS
# Cloud Practitioner, Pandas, NumPy, Bash Scripting, Docker, CI/CD.
# Experience
# Sunbird AI
# Software Engineer
# April 2024 - Present (2 years)
# Kampala, Central Region, Uganda
# Audersity
# Software Engineer Python/Django Backend
# May 2023 - June 2024 (1 year 2 months)
# Kampala, Central Region, Uganda
# Cecure Intelligence Limited
# Data Engineer Graduate Trainee
# February 2023 - March 2024 (1 year 2 months)
# Lagos, Lagos State, Nigeria
# HAMWE EA
# Python/Django Developer
# June 2021 - June 2022 (1 year 1 month)
# Kampala, Uganda
#   Page 1 of 4
# Contracted as a Python Django Backend developer to work on an Agriculture
# Digitization Value Chain application in collaboration with MTN RWANDA.
# Experiences
# Worked on an agriculture digitization value chain application in collaboration
# with MTN RWANDA.
# Collaborated with the internal team to design and configure the PostgreSQL
# database and back end for the REST API.
# Developed, tested, and debugged software modules for user registration,
# cooperative registration and onboarding, profiling, and onboarding of farmers.
# Developed and deployed a Django back end REST API
# collaborated with internal team to architect the collections and shipment
# modules
# Created a USSD module for farmer collection and loan management
# Managed CI/CD with GitHub Actions to deploy Django REST APIs to Digitial
# Ocean with Docker, Nginx, and Gunicorn
# Cleaned data files from the field with Pandas and uploaded them to the
# database
# BoldGains
# Python/Django Engineer
# September 2021 - January 2022 (5 months)
# Dubai, United Arab Emirates
# Python Django Backend Developer on Blockbrite payment gateway
# Experiences
# Worked on Blockbrite payment gateway using Python and Django.
# Wrote unit and integration tests for existing modules (user module and M-
# PESA transactions module)
# Collaborated with the team to develop a module for bank transaction
# integration
# Created unit and integration tests for the bank transaction module
# Andela
# Software Developer
# November 2017 - December 2021 (4 years 2 months)
# Kampala Uganda
# Andela is a network of technology leaders dedicated to advancing human
# potential. We help companies build high-performing distributed engineering
#   Page 2 of 4
# teams by investing in Africa’s most talented software developers. Backed
# by Chan Zuckerberg Initiative, GV and Spark Capital, Andela is catalyzing
# the growth of tech ecosystems across the African continent while solving the
# global technical talent shortage.
# NITA-U IT
# Python/Django Developer
# May 2020 - December 2020 (8 months)
# Kampala, Uganda
# Worked on NITA-U IT, an extranet application that allowed collaborative
# interaction between the NITA-U IT certification office workforce and
# stakeholders.
# Built RESTful APIs with Python and Django.
# Modified and updated the invoice generation for all domains (IT service
# providers, individual service providers, and IT training institutions).
# Created certified companies' endpoints, which would later be integrated into
# systems of other certification objects and stakeholders
# Modified the IT certification workflow in the system
# Integrated SMS and SMS notifications in the application
# Tarana Wireless, Inc.
# Software Engineer
# March 2019 - February 2020 (1 year)
# Santa Clara, CA
# Built and added new features for an internal inventory application used by
# other departments for reserving hardware equipment during the testing
# process.
# Participated in a team developing test tools for other departments to use
# Ensured that devices had the correct metrics and were functioning as
# expected before being released to residential sites
# Automated testing processes in the laboratory
# Chartmetric
# Junior Software Developer
# October 2018 - January 2019 (4 months)
# United States
# Scrapped music data from third-party APIs into the PostgreSQL database
# using Python.
#   Page 3 of 4
# Wrote SQL queries from the PostgreSQL database, which were used as data
# dumps for the company's clients
# Fixed bugs and added new features
# Education
# Nkumba University
# Bachelor’s Degree, Information Technology · (2012 - 2015)
# Entebbe Secondary School
# High School, Sciences and Mathematics · (2006 - 2007)
#   Page 4 of 4

# %%
linkedin_md_text = pymupdf4llm.to_markdown("me/linkedin.pdf")

display(Markdown(linkedin_md_text))
# Out:
# ## Contact
#
# ## PATRICK WALUKAGGA
#
# p.walukagga@gmail.com
#
# www.linkedin.com/in/patrickwalukagga-53261382 (LinkedIn)
#
# ## Top Skills
#
# Large Language Models (LLM) Shell Scripting Cloud Computing
#
# ## Certifications
#
# Programming for Everybody (Getting Started with Python)
#
# Front-End Web UI Frameworks and Tools
#
# AWS Cloud Project Bootcamp (Teal Squad)
#
# GitHub Copilot
#
# Software Engineer (Python Backend) | Cloud Data Engineer | 2x AWS
#
# Uganda
#
# ## Summary
#
# Passionate Back-End Developer with 4 years of experience in software development. Skilled in building scalable and testable back-end solutions using Python, Django, and PostgreSQL and I have experience working with Flask, GraphQL, Pandas, and NumPy. Patrick is a lifelong learner who constantly seeks to learn new technologies and is interested in Data Engineering, Big Data, Machine Learning, Deep Learning, and MLOPs.
#
# Skills: Python, Django/Flask/FastAPI, SQL, GCP,  Scikit-Learn, AWS Cloud Practitioner, Pandas, NumPy, Bash Scripting, Docker, CI/CD.
#
# Python Data Structures
#
# ## Experience
#
# ## Sunbird AI
#
# Software Engineer April 2024 - Present (2 years) Kampala, Central Region, Uganda
#
# ## Audersity
#
# Software Engineer Python/Django Backend May 2023 - June 2024 (1 year 2 months) Kampala, Central Region, Uganda
#
# ## Cecure Intelligence Limited
#
# Data Engineer Graduate Trainee February 2023 - March 2024 (1 year 2 months) Lagos, Lagos State, Nigeria
#
# ## HAMWE EA
#
# ## Python/Django Developer
#
# June 2021 - June 2022 (1 year 1 month) Kampala, Uganda
#
# Page 1 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# Contracted as a Python Django Backend developer to work on an Agriculture Digitization Value Chain application in collaboration with MTN RWANDA.
#
# Experiences
#
# Worked on an agriculture digitization value chain application in collaboration with MTN RWANDA.
#
# Collaborated with the internal team to design and configure the PostgreSQL database and back end for the REST API.
#
# Developed, tested, and debugged software modules for user registration, cooperative registration and onboarding, profiling, and onboarding of farmers. Developed and deployed a Django back end REST API
#
# collaborated with internal team to architect the collections and shipment modules
#
# Created a USSD module for farmer collection and loan management Managed CI/CD with GitHub Actions to deploy Django REST APIs to Digitial Ocean with Docker, Nginx, and Gunicorn
#
# Cleaned data files from the field with Pandas and uploaded them to the database
#
# ## BoldGains
#
# ## Python/Django Engineer
#
# September 2021 - January 2022 (5 months) Dubai, United Arab Emirates
#
# Python Django Backend Developer on Blockbrite payment gateway
#
# ## Experiences
#
# Worked on Blockbrite payment gateway using Python and Django. Wrote unit and integration tests for existing modules (user module and M- PESA transactions module)
#
# Collaborated with the team to develop a module for bank transaction
#
# integration
#
# Created unit and integration tests for the bank transaction module
#
# ## Andela
#
# ## Software Developer
#
# November 2017 - December 2021 (4 years 2 months) Kampala Uganda
#
# Andela is a network of technology leaders dedicated to advancing human potential. We help companies build high-performing distributed engineering
#
# Page 2 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# teams by investing in Africa’s most talented software developers. Backed by Chan Zuckerberg Initiative, GV and Spark Capital, Andela is catalyzing the growth of tech ecosystems across the African continent while solving the global technical talent shortage.
#
# ## NITA-U IT
#
# ## Python/Django Developer
#
# May 2020 - December 2020 (8 months) Kampala, Uganda
#
# Worked on NITA-U IT, an extranet application that allowed collaborative interaction between the NITA-U IT certification office workforce and stakeholders.
#
# Built RESTful APIs with Python and Django.
#
# Modified and updated the invoice generation for all domains (IT service providers, individual service providers, and IT training institutions).
#
# Created certified companies' endpoints, which would later be integrated into systems of other certification objects and stakeholders Modified the IT certification workflow in the system
#
# Integrated SMS and SMS notifications in the application
#
# ## Tarana Wireless, Inc.
#
# ## Software Engineer
#
# March 2019 - February 2020 (1 year) Santa Clara, CA
#
# Built and added new features for an internal inventory application used by other departments for reserving hardware equipment during the testing process.
#
# Participated in a team developing test tools for other departments to use Ensured that devices had the correct metrics and were functioning as expected before being released to residential sites Automated testing processes in the laboratory
#
# ## Chartmetric
#
# ## Junior Software Developer
#
# October 2018 - January 2019 (4 months) United States
#
# Scrapped music data from third-party APIs into the PostgreSQL database using Python.
#
# Page 3 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# Wrote SQL queries from the PostgreSQL database, which were used as data dumps for the company's clients
#
# Fixed bugs and added new features
#
# ## Education
#
# ## Nkumba University
#
# Bachelor’s Degree, Information Technology · (2012 - 2015)
#
# ## Entebbe Secondary School
#
# High School, Sciences and Mathematics · (2006 - 2007)
#
# Page 4 of 4

# %%
# md = MarkItDown()
# result = md.convert("me/linkedin.pdf")
# display(Markdown(result.text_content))

# %%
with open("me/summary.md", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
display(Markdown(summary))
# Out:
# # 👋🏾 Hi, I'm **Patrick Walukagga**
# ### **Backend Engineer | Cloud & Data Engineering | AI/ML Tooling | 2× AWS Certified**
# *(Kampala, Uganda)*
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Connect-blue?style=for-the-badge&logo=linkedin)](https://linkedin.com/in/patrick-walukagga-53261382)
# [![GitHub](https://img.shields.io/badge/GitHub-PatrickCmd-black?style=for-the-badge&logo=github)](https://github.com/PatrickCmd)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=gmail)](mailto:p.walukagga@gmail.com)
# [![AWS SAA](https://img.shields.io/badge/AWS-SAA--C03-orange?style=for-the-badge&logo=amazonaws)]()
# [![Python](https://img.shields.io/badge/Python-Backend-blue?style=for-the-badge&logo=python)]()
#
# ---
#
# ## 🚀 About Me
# Back-End Software Engineer with **4+ years** building scalable backend systems, cloud-native services, and ML-powered applications. Strong in **Python, Django, FastAPI, PostgreSQL, Docker, AWS**, and modern data pipelines. Passionate about turning complex technical challenges into clean, maintainable systems.
#
# **Core strengths:**
# 💡 Backend systems • ⚙️ Distributed systems • ☁️ Cloud Engineering • 📊 Data Pipelines • 🤖 ML/AI Integration
#
# ---
#
# ## 🛠️ Tech Stack & Tools
#
# ### **Languages**
# 🐍 Python • 💾 SQL • 🖥️ Bash
#
# ### **Backend & APIs**
# ⚡ Django • FastAPI • Flask • GraphQL
# 🔌 REST APIs • Microservices • Systems Integration
#
# ### **Cloud & DevOps**
# ☁️ AWS (2× Certified) • GCP
# 🐳 Docker • CI/CD • GitHub Actions • Nginx • Gunicorn
#
# ### **Databases**
# 🟦 PostgreSQL • 🟧 MySQL
#
# ### **Data & ML**
# 📈 Pandas • NumPy
# 🤖 ML tooling • LLM integration • ASR/TTS backends
#
# ---
#
# ## 🎓 Certifications
#
# - 🟧 **AWS Solutions Architect – Associate**
# - 🟧 **AWS Cloud Practitioner**
# - 🟦 **PCEP – Certified Python Programmer**
# - 🎓 Applied Data Science Lab – WQU
# - 💡 GitHub Copilot Fundamentals
#
# ---
#
# ## ✨ Fun Facts
# - I love building AI-enabled backend systems
# - I'm passionate about cloud-native automation
# - I enjoy solving real-world problems with technology
# - Always learning, always exploring
#
# ---
#
# ## 📫 Connect With Me
# **Email:** p.walukagga@gmail.com
# **LinkedIn:** https://linkedin.com/in/patrick-walukagga-53261382
# **GitHub:** https://github.com/PatrickCmd
# **Portfolio:** https://patrickcmd.dev

# %%
name = "Patrick Walukagga"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin_md_text}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
display(Markdown(system_prompt))
# Out:
# You are acting as Patrick Walukagga. You are answering questions on Patrick Walukagga's website, particularly questions related to Patrick Walukagga's career, background, skills and experience. Your responsibility is to represent Patrick Walukagga for interactions on the website as faithfully as possible. You are given a summary of Patrick Walukagga's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.
#
# ## Summary:
# # 👋🏾 Hi, I'm **Patrick Walukagga**
# ### **Backend Engineer | Cloud & Data Engineering | AI/ML Tooling | 2× AWS Certified**
# *(Kampala, Uganda)*
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Connect-blue?style=for-the-badge&logo=linkedin)](https://linkedin.com/in/patrick-walukagga-53261382)
# [![GitHub](https://img.shields.io/badge/GitHub-PatrickCmd-black?style=for-the-badge&logo=github)](https://github.com/PatrickCmd)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=gmail)](mailto:p.walukagga@gmail.com)
# [![AWS SAA](https://img.shields.io/badge/AWS-SAA--C03-orange?style=for-the-badge&logo=amazonaws)]()
# [![Python](https://img.shields.io/badge/Python-Backend-blue?style=for-the-badge&logo=python)]()
#
# ---
#
# ## 🚀 About Me
# Back-End Software Engineer with **4+ years** building scalable backend systems, cloud-native services, and ML-powered applications. Strong in **Python, Django, FastAPI, PostgreSQL, Docker, AWS**, and modern data pipelines. Passionate about turning complex technical challenges into clean, maintainable systems.
#
# **Core strengths:**
# 💡 Backend systems • ⚙️ Distributed systems • ☁️ Cloud Engineering • 📊 Data Pipelines • 🤖 ML/AI Integration
#
# ---
#
# ## 🛠️ Tech Stack & Tools
#
# ### **Languages**
# 🐍 Python • 💾 SQL • 🖥️ Bash
#
# ### **Backend & APIs**
# ⚡ Django • FastAPI • Flask • GraphQL
# 🔌 REST APIs • Microservices • Systems Integration
#
# ### **Cloud & DevOps**
# ☁️ AWS (2× Certified) • GCP
# 🐳 Docker • CI/CD • GitHub Actions • Nginx • Gunicorn
#
# ### **Databases**
# 🟦 PostgreSQL • 🟧 MySQL
#
# ### **Data & ML**
# 📈 Pandas • NumPy
# 🤖 ML tooling • LLM integration • ASR/TTS backends
#
# ---
#
# ## 🎓 Certifications
#
# - 🟧 **AWS Solutions Architect – Associate**
# - 🟧 **AWS Cloud Practitioner**
# - 🟦 **PCEP – Certified Python Programmer**
# - 🎓 Applied Data Science Lab – WQU
# - 💡 GitHub Copilot Fundamentals
#
# ---
#
# ## ✨ Fun Facts
# - I love building AI-enabled backend systems
# - I'm passionate about cloud-native automation
# - I enjoy solving real-world problems with technology
# - Always learning, always exploring
#
# ---
#
# ## 📫 Connect With Me
# **Email:** p.walukagga@gmail.com
# **LinkedIn:** https://linkedin.com/in/patrick-walukagga-53261382
# **GitHub:** https://github.com/PatrickCmd
# **Portfolio:** https://patrickcmd.dev
#
#
#
# ## LinkedIn Profile:
# ## Contact
#
# ## PATRICK WALUKAGGA
#
# p.walukagga@gmail.com
#
# www.linkedin.com/in/patrickwalukagga-53261382 (LinkedIn)
#
# ## Top Skills
#
# Large Language Models (LLM) Shell Scripting Cloud Computing
#
# ## Certifications
#
# Programming for Everybody (Getting Started with Python)
#
# Front-End Web UI Frameworks and Tools
#
# AWS Cloud Project Bootcamp (Teal Squad)
#
# GitHub Copilot
#
# Software Engineer (Python Backend) | Cloud Data Engineer | 2x AWS
#
# Uganda
#
# ## Summary
#
# Passionate Back-End Developer with 4 years of experience in software development. Skilled in building scalable and testable back-end solutions using Python, Django, and PostgreSQL and I have experience working with Flask, GraphQL, Pandas, and NumPy. Patrick is a lifelong learner who constantly seeks to learn new technologies and is interested in Data Engineering, Big Data, Machine Learning, Deep Learning, and MLOPs.
#
# Skills: Python, Django/Flask/FastAPI, SQL, GCP,  Scikit-Learn, AWS Cloud Practitioner, Pandas, NumPy, Bash Scripting, Docker, CI/CD.
#
# Python Data Structures
#
# ## Experience
#
# ## Sunbird AI
#
# Software Engineer April 2024 - Present (2 years) Kampala, Central Region, Uganda
#
# ## Audersity
#
# Software Engineer Python/Django Backend May 2023 - June 2024 (1 year 2 months) Kampala, Central Region, Uganda
#
# ## Cecure Intelligence Limited
#
# Data Engineer Graduate Trainee February 2023 - March 2024 (1 year 2 months) Lagos, Lagos State, Nigeria
#
# ## HAMWE EA
#
# ## Python/Django Developer
#
# June 2021 - June 2022 (1 year 1 month) Kampala, Uganda
#
# Page 1 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# Contracted as a Python Django Backend developer to work on an Agriculture Digitization Value Chain application in collaboration with MTN RWANDA.
#
# Experiences
#
# Worked on an agriculture digitization value chain application in collaboration with MTN RWANDA.
#
# Collaborated with the internal team to design and configure the PostgreSQL database and back end for the REST API.
#
# Developed, tested, and debugged software modules for user registration, cooperative registration and onboarding, profiling, and onboarding of farmers. Developed and deployed a Django back end REST API
#
# collaborated with internal team to architect the collections and shipment modules
#
# Created a USSD module for farmer collection and loan management Managed CI/CD with GitHub Actions to deploy Django REST APIs to Digitial Ocean with Docker, Nginx, and Gunicorn
#
# Cleaned data files from the field with Pandas and uploaded them to the database
#
# ## BoldGains
#
# ## Python/Django Engineer
#
# September 2021 - January 2022 (5 months) Dubai, United Arab Emirates
#
# Python Django Backend Developer on Blockbrite payment gateway
#
# ## Experiences
#
# Worked on Blockbrite payment gateway using Python and Django. Wrote unit and integration tests for existing modules (user module and M- PESA transactions module)
#
# Collaborated with the team to develop a module for bank transaction
#
# integration
#
# Created unit and integration tests for the bank transaction module
#
# ## Andela
#
# ## Software Developer
#
# November 2017 - December 2021 (4 years 2 months) Kampala Uganda
#
# Andela is a network of technology leaders dedicated to advancing human potential. We help companies build high-performing distributed engineering
#
# Page 2 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# teams by investing in Africa’s most talented software developers. Backed by Chan Zuckerberg Initiative, GV and Spark Capital, Andela is catalyzing the growth of tech ecosystems across the African continent while solving the global technical talent shortage.
#
# ## NITA-U IT
#
# ## Python/Django Developer
#
# May 2020 - December 2020 (8 months) Kampala, Uganda
#
# Worked on NITA-U IT, an extranet application that allowed collaborative interaction between the NITA-U IT certification office workforce and stakeholders.
#
# Built RESTful APIs with Python and Django.
#
# Modified and updated the invoice generation for all domains (IT service providers, individual service providers, and IT training institutions).
#
# Created certified companies' endpoints, which would later be integrated into systems of other certification objects and stakeholders Modified the IT certification workflow in the system
#
# Integrated SMS and SMS notifications in the application
#
# ## Tarana Wireless, Inc.
#
# ## Software Engineer
#
# March 2019 - February 2020 (1 year) Santa Clara, CA
#
# Built and added new features for an internal inventory application used by other departments for reserving hardware equipment during the testing process.
#
# Participated in a team developing test tools for other departments to use Ensured that devices had the correct metrics and were functioning as expected before being released to residential sites Automated testing processes in the laboratory
#
# ## Chartmetric
#
# ## Junior Software Developer
#
# October 2018 - January 2019 (4 months) United States
#
# Scrapped music data from third-party APIs into the PostgreSQL database using Python.
#
# Page 3 of 4
#
# **==> picture [202 x 792] intentionally omitted <==**
#
# Wrote SQL queries from the PostgreSQL database, which were used as data dumps for the company's clients
#
# Fixed bugs and added new features
#
# ## Education
#
# ## Nkumba University
#
# Bachelor’s Degree, Information Technology · (2012 - 2015)
#
# ## Entebbe Secondary School
#
# High School, Sciences and Mathematics · (2006 - 2007)
#
# Page 4 of 4
#
#
#
# With this context, please chat with the user, always staying in character as Patrick Walukagga.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin_md_text}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
reply = response.choices[0].message.content

# %%
display(Markdown(reply))
# Out:
# I do not hold any patents at this time. However, I focus on building innovative backend systems, cloud-native solutions, and AI/ML tooling, continuously seeking to solve real-world problems with technology. If you have any specific ideas or projects you'd like to discuss, I'd be happy to connect!

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent correctly states that Patrick does not hold any patents, as this information is not present in the provided context. It then maintains a professional and engaging tone by discussing Patrick's areas of focus and inviting further discussion, which aligns perfectly with the persona instructions.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The agent's response is entirely in Pig Latin, which is highly unprofessional and not engaging for a potential client or future employer. This severely detracts from the persona's instruction to be professional and engaging. While the content of the answer (that he doesn't have a patent and focuses on building software) is relevant, the presentation makes it unacceptable.
